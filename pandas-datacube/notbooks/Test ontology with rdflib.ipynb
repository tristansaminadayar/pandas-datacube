# %%
import rdflib

# %%
g = rdflib.Graph()
uri = "http://kaiko.getalp.org/static/datamodel/2.1.1/ontology.xml"
g.parse(uri, format='xml')
#g.compute_qname("http://kaiko.getalp.org/dbnary#dbnaryStatisticsDataStructure", generate=True)
#print(g.serialize(format="turtle").decode("utf-8"))
for a,b,c in g:
    print(a, b, c)
# Out:
# http://kaiko.getalp.org/dbnary#translationsWithTextualGloss http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty
# Nfea6adf0504f44b8a59d4754b9417ab6 http://www.w3.org/1999/02/22-rdf-syntax-ns#rest Nf1b794cd2fc24179b9ee04e9efbf02a7
# Na8409196c9e34cb4b9f1fff2640f23b7 http://www.w3.org/1999/02/22-rdf-syntax-ns#first http://www.w3.org/ns/lemon/ontolex#LexicalEntry
# http://kaiko.getalp.org/dbnary#synonym http://www.w3.org/2000/01/rdf-schema#range N84ba68974487405dba46f2d047d79284
# N86768474f61147ddb25f1b43fff3e5b2 http://www.w3.org/1999/02/22-rdf-syntax-ns#first http://www.w3.org/ns/lemon/ontolex#LexicalEntry
# http://kaiko.getalp.org/dbnary#senseNumber http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#DatatypeProperty
# http://kaiko.getalp.org/dbnary#usage http://www.w3.org/2000/01/rdf-schema#comment Usage note that is used to further annotate the target of the translation.
# ...
