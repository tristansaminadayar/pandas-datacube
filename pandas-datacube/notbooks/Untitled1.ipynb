# %%
# %run ../../src/pandas-datacube/pandas_datacube
ENDPOINT: str = "http://kaiko.getalp.org/sparql"
PREFIXES: dict[str] = {'dbnary': 'http://kaiko.getalp.org/dbnary#',
                       'dbnstats': 'http://kaiko.getalp.org/dbnary/statistics/',
                       'lime': 'http://www.w3.org/ns/lemon/lime#'}

# %%
a = get_datacube(ENDPOINT, prefixes = PREFIXES, restrictions = {'dbnary:observationLanguage': ["es", "fr"], 'dbnary:wiktionaryDumpVersion': ['20210620']})
a
# Out:
#                                                                                              count
# observationLanguage wiktionaryDumpVersion nymRelation
# es                  20210620              http://kaiko.getalp.org/dbnary#antonym              2827
#                                           http://kaiko.getalp.org/dbnary#approximateSynonym      0
#                                           http://kaiko.getalp.org/dbnary#holonym                 0
#                                           http://kaiko.getalp.org/dbnary#hypernym             1589
#                                           http://kaiko.getalp.org/dbnary#hyponym               913
#                                           http://kaiko.getalp.org/dbnary#meronym                 0
#                                           http://kaiko.getalp.org/dbnary#synonym             25821
#                                           http://kaiko.getalp.org/dbnary#troponym                0
# ...
